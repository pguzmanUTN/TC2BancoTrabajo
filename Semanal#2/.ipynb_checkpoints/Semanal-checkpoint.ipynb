# %% [markdown]
# # Semanal#2
#
# ## Autor: Guzmán Pedro

# %%
# Librerías externas NumPy, SciPy y Matplotlib
from scipy.signal import TransferFunction
import scipy.signal as signal
import matplotlib.pyplot as plt
import numpy as np
#import math
# Librería de TC2, esta la vas a usar mucho
from pytc2.sistemas_lineales import pzmap
from IPython.display import display, Math

# %% [markdown]
# ## Resolución hecha a mano

# %% [markdown]
# En la resolucion en PDF se encuentran resueltos el primer Bonus y los tres incisos obligatorios

# %%
from IPython.display import IFrame
IFrame("./Semanal2_ResolucionAMano.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="./Semanal2_ResolucionAMano.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Bonus Simulación Transferencia Normalizada

# %%
w0=1
Q=1 #Valor generico a Graficar
K=-1


# Definición de la función de transferencia
numerador = [K] 
denominador = [1, w0/Q, w0**2]  

# Crear la función de transferencia
my_tf = TransferFunction( numerador, denominador)

# Define el rango de frecuencias para la simulación
frecuencias = np.logspace(-3, 3, 500)   

# Calcular la respuesta en frecuencia
w, mag, fase = signal.bode(my_tf, frecuencias)

# Graficar la magnitud
plt.figure(figsize=(10, 6))

# Magnitud (en dB)
plt.subplot(2, 1, 1)
plt.semilogx(w, mag)  
plt.title('Respuesta en Magnitud y Fase de la Transferencia')
plt.ylabel('Modulo (Amplitud)')
plt.grid()

# Fase
plt.subplot(2, 1, 2)
plt.semilogx(w, fase)
plt.xlabel('Frecuencia (rad/s)')
plt.ylabel('Fase (grados)')
plt.grid()



plt.show()

plt.close('all')

pzmap(my_tf, fig_id=2) #S plane pole/zero plot
# Out:
# (2, <Axes: xlabel='$\\sigma$', ylabel='j$\\omega$'>)

# %% [markdown]
# ## Bonus LTSPICE
#
# Las normalizaciones en frecuencia e impedancia se usaron tomando W0 para la normalización en frecuencia y R3 para la normalización en impedancia
#
#
# ### Curvas Pasabajos
#
# La parametrización normalizada en frecuencia e impedancia usada para graficar el pasa bajos es
#
# $$
# H(s) = \frac{K}{s^2 + \frac{1}{Q}s + 1} = \frac{ \frac{-1}{R1}}{s^2 + \frac{1}{R2}s + 1}
# $$
#
# ![image.png](attachment:79e5fee0-e11c-4ae5-9b22-7bd7203f003c.png)
#
# ![image.png](attachment:cefb4854-34c9-4457-bec1-6c57918f164f.png)
#
# ![image.png](attachment:b72a67ae-6a1a-47f0-ada9-358bd94c323f.png)
#
#
# ### Curvas Pasabanda
#
# La parametrizacion normalizada en frecuencia e impedancia usada para graficar el pasabanda es
#
# $$
# H(s) = \frac{K \cdot \frac{1}{Q}}{s^2 + \frac{1}{Q}s + 1}  =  \frac{ \frac{-1}{R1}s}{s^2 + \frac{1}{R2}s + 1}
# $$
#
# Como se puede ver hay una leve diferencia en la parametrización del Pasabajos y del pasa banda, esto es nada mas para que en la frecuencia w0 nos quede la ganancia K, mientras que en el pasabajos, a frecuencias bajas tambien nos de la ganancia K. Es por un tema de conveniencia.
#
# ![image.png](attachment:ec947512-f69a-4bab-8b45-240f53d04d05.png)
#
# ![image.png](attachment:fc7dace4-4450-4538-9309-027795205cfb.png)
#
# ![image.png](attachment:fd116796-e189-479a-93a7-5e10ba90bc1a.png)
