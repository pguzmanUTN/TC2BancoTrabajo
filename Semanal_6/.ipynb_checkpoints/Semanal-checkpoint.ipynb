# %% [markdown]
# # Semanal#6
#
# ## Autor: Guzmán Pedro

# %% [markdown]
# ## Resolución hecha a mano

# %% [markdown]
# En la resolucion en PDF se encuentran resueltos todos los incisos, parte de resolución del primer bonus y la verificación analitica del segundo bonus.

# %%
from IPython.display import IFrame
IFrame("./Semanal6_ResolucionAMano.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="./Semanal6_ResolucionAMano.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Bonus 2
#
# ![image.png](attachment:74b7a8d5-231c-442e-abe7-90804aea86b6.png)
#
# ![image.png](attachment:d9693a0f-ab03-4df3-896f-0405a81dac1c.png)
#
# Hay dos lineas que se encuentran juntas y por eso en ambos graficos solo se ven tres lineas, cumple perfectamente lo que puse en la matriz
#
# ![image.png](attachment:98419281-fc9d-4339-b9a8-22c82ff406b0.png)
#
# Los resultados analiticos dan igual que los resultados simulados
#
# # Extra redes activas
#
# ![image.png](attachment:de368a64-cffc-4e6b-8808-dab08c7f49fc.png)
#
#
# ![image.png](attachment:b3bdaab0-19e8-481c-9996-4b4e2995dcc0.png)
#
#
# Simule tambien la topologia activa por curiosidad y da perfectamente lo que puse en la matriz, en este caso no existe para esta topologia parametros admitancia
#
# ![image.png](attachment:f389e176-4a5a-4f62-a09b-c1a5fa4988b0.png)
#
#
# ![image.png](attachment:3fab16cf-f4bd-4ffd-af1d-09a43ce0e389.png)
#
#
# Esta topologia activa tambien da perfectamente, no esta ploteada la fase, pero da bien el signo con el cursor
#
# ![image.png](attachment:0489472f-5c00-4357-a76b-9e527a9a087a.png)
